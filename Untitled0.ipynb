# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/MyDrive/slacml-kmi2020/
# Out:
# /content/drive/MyDrive/slacml-kmi2020

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/slacml-kmi2020/.git/

# %%
# !git config --global user.email "eguchi.kazuki@e.mbox.nagoya-u.ac.jp"
# !git config --global user.name "KazukiEguchi"

# %%
# !git add *
# !git commit -m "new"
# Out:
# [master (root-commit) 0880452] new
#  119 files changed, 353517 insertions(+)
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig1.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig1.png
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig2a.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig2b.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig2c.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig2d.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig3a.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig4.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig5.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig6a3.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig6b4.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig6c5.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig6d6.pdf
#  create mode 100644 ClassicalEnsembleMethods/Errata/Fig6e10.pdf
# ...

# %%
# !git remote set-url origin https://colab.research.google.com/github/KazukiEguchi/slacml-kmi2020.git

# %%
# !git push origin master
# Out:
# fatal: https://colab.research.google.com/github/KazukiEguchi/slacml-kmi2020.git/info/refs not valid: is this a git repository?

# %%
# !git remote -v
# Out:
# origin	https://github.com/KazukiEguchi/slacml-kmi2020.git (fetch)
# origin	https://github.com/KazukiEguchi/slacml-kmi2020.git (push)
